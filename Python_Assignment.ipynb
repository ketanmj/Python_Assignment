# %% [markdown]
# # TASK ONE
#
# ## Numbers and Variables

# %% [markdown]
# 1. Create three variables in a single line and assign values to them in such a manner that each one of
# them belongs to a different data type.

# %%
x, y, z = 2, 3.04, 'string'

print(f'x : {x}')
print(f'y : {y}')
print(f'z : {z}')
# Out:
# x : 2
# y : 3.04
# z : string

# %% [markdown]
# 2. Create a variable of type complex and swap it with another variable of type integer.

# %%
cmp = complex(4, 5)

num = 6

print(f'cmp : {cmp}')
print(f'num : {num}')

# Swapping

tmp = cmp
cmp = num
num = tmp

print('\nAfter swapping:\n')
print(f'cmp : {cmp}')
print(f'num : {num}')
# Out:
# cmp : (4+5j)
# num : 6
#
# After swapping:
#
# cmp : 6
# num : (4+5j)

# %% [markdown]
# 3. Swap two numbers using a third variable and do the same task without using any third variable.

# %%
# Swapping using third variable

a = 78
b = 99

print(f'a : {a}')
print(f'b : {b}')

tmp = a
a = b
b = tmp

print('\nAfter swapping:\n')
print(f'a : {a}')
print(f'b : {b}')
# Out:
# a : 78
# b : 99
#
# After swapping:
#
# a : 99
# b : 78

# %%
# Swapping without using third variable

a = 78
b = 99

print(f'a : {a}')
print(f'b : {b}')

a = a + b
b = a - b
a = a - b

print('\nAfter swapping:\n')
print(f'a : {a}')
print(f'b : {b}')
# Out:
# a : 78
# b : 99
#
# After swapping:
#
# a : 99
# b : 78

# %% [markdown]
# 4. Write a program that takes input from the user and prints it using both Python 2.x and Python 3.x
# Version.

# %%
# %%python2
# # Python 2
#
# text = raw_input("Enter some text: ")
#
# print text

# %%
# Python 3

text = input("Enter some text: ")

print(text)
# Out:
# Enter some text: Python
# Python

# %% [markdown]
# 5. Write a program to complete the task given below:
# Ask users to enter any 2 numbers in between 1-10 , add the two numbers and keep the sum in another variable called z. Add 30 to z and store the output in variable result and print result as the
# final output.

# %%
num1 = input('Enter a number between 1 and 10: ')
num2 = input('Enter another number between 1 and 10: ')

z = int(num1) + int(num2)
result = z + 30

print(f'Result : {result}')
# Out:
# Enter a number between 1 and 10: 3
# Enter another number between 1 and 10: 4
# Result : 37

# %% [markdown]
# 6. Write a program to check the data type of the entered values.
# HINT: Printed output should say - The data type of the input value is : int/float/string/etc

# %%
import re

regex_integer = '^[0-9]+$'
regex_float = '^[0-9]+[.][0-9]*$|^[0-9]*[.][0-9]+$'

value = input('Enter a value: ')

integer = re.match(regex_integer, value)
flt = re.match(regex_float, value)

if integer:
  value = int(value)
elif flt:
  value = float(value)

print(f'The data type of the input value is: {type(value)}')
# Out:
# Enter a value: 4.9
# The data type of the input value is: <class 'float'>

# %% [markdown]
# 7. Create Variables using formats such as Upper CamelCase, Lower CamelCase, SnakeCase and
# UPPERCASE.
# (Refer: https://capitalizemytitle.com/camel-case/)

# %%
# Upper camel case
IntegerVariable = 4

# Lower camel case
floatVariable = 5.6

# Snake case
string_variable = 'string'

# Uppercase
VARIABLE = '1.1'

# %% [markdown]
# 8. If one data type value is assigned to ‘a’ variable and then a different data type value is assigned to ‘a’
# again. Will it change the value? If Yes then Why?

# %% [markdown]
#         Yes, the variable 'a' will change value, because python is a dynamically typed language. So, the variable type is assessed during runtime.

# %% [markdown]
# # TASK TWO
#
# ## Operators and Decision Making Statement

# %% [markdown]
# 1. Write a program in Python to perform the following operation:
#
#
#
# *   If a number is divisible by 3 it should print “Consultadd” as a string
# *   If a number is divisible by 5 it should print “Python Training” as a string
# *   If a number is divisible by both 3 and 5 it should print “Consultadd - Python Training” as a string.

# %%
n = input('Enter a number: ')

n = int(n)

if (n % 3 == 0) & (n % 5 == 0):
  print('ConsultAdd - Python Training')
elif (n % 3 == 0):
  print('ConsultAdd')
elif (n % 5 == 0):
  print('Python Training')
# Out:
# Enter a number: 30
# ConsultAdd - Python Training

# %% [markdown]
# 2. Write a program in Python to perform the following operator based task:
#
# *   Ask user to choose the following option first:
#
#       If User Enter 1 - Addition
#
#       If User Enter 2 - Subtraction
#
#       If User Enter 3 - Division
#
#       If User Enter 4 - Multiplication
#
#       If User Enter 5 - Average
#
# *   Ask user to enter two numbers and keep those numbers in variables num1 and num2 respectively for the first 4 options mentioned above.
# *   Ask the user to enter two more numbers as first and second for calculating the average as soon as the user chooses an option 5.
# *   At the end if the answer of any operation is Negative print a statement saying “NEGATIVE”
# *   NOTE: At a time a user can only perform one action.

# %%
choice = input('Enter a number between 1 & 5 for Addition, Sutraction, Division, Multiplication, Average: ')
choice = int(choice)

if choice < 5:
  num1 = input('Enter first number: ')
  num2 = input('Enter second number: ')
  num1, num2 = float(num1), float(num2)

  if choice == 1:
    result = num1 + num2
  if choice == 2:
    result = num1 - num2
  if choice == 3:
    result = num1 / num2
  if choice == 4:
    result = num1 * num2

elif choice == 5:
  first = input('Enter first number: ')
  second = input('Enter second number: ')
  first, second = float(first), float(second)

  result = (first + second) / 2

if result < 0:
  print('NEGATIVE')
else:
  print(f'Result: {result}')
# Out:
# Enter a number between 1 & 5 for Addition, Sutraction, Division, Multiplication, Average: 2
# Enter first number: 5
# Enter second number: 9
# NEGATIVE

# %% [markdown]
# 3. Write a program in Python to implement the given flowchart:
# ![Assignment_Image.png](data:image/png;base64,...)

# %%
a, b, c = 10, 20, 30
avg = (a + b + c) / 3
print(f'Average = {avg}')

greater_than_a = (avg > a)
greater_than_b = (avg > b)
greater_than_c = (avg > c)

if greater_than_a & greater_than_b & greater_than_c:
  print('Average is higher than a, b, c')
elif greater_than_a & greater_than_b:
  print('Average is higher than a, b')
elif greater_than_a & greater_than_c:
  print('Average is higher than a, c')
elif greater_than_b & greater_than_c:
  print('Average is higher than b, c')
elif greater_than_a:
  print('Average is just higher than a')
elif greater_than_b:
  print('Average is just higher than b')
elif greater_than_c:
  print('Average is just higher than c')
# Out:
# Average = 20.0
# Average is just higher than a

# %% [markdown]
# 4. Write a program in Python to break and continue if the following cases occurs:
#
# *   If user enters a negative number just break the loop and print “It’s Over”
# *   If user enters a positive number just continue in the loop and print “Good Going”

# %%
while True:
  num = input('Enter a number: ')
  num = int(num)
  
  if num < 0:
    print("It's Over")
    break
  elif num > 0:
    print("Good Going")
# Out:
# Enter a number: 5
# Good Going
# Enter a number: 8
# Good Going
# Enter a number: -2
# It's Over

# %% [markdown]
# 5. Write a program in Python which will find all such numbers which are divisible by 7 but are not a
# multiple of 5, between 2000 and 3200.

# %%
num_list = []

for num in range(2000, 3201):
  if (num % 7 == 0) & (num % 5 != 0):
    num_list.append(num)

print(num_list)
# Out:
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128, 2142, 2149, 2156, 2163, 2177, 2184, 2191, 2198, 2212, 2219, 2226, 2233, 2247, 2254, 2261, 2268, 2282, 2289, 2296, 2303, 2317, 2324, 2331, 2338, 2352, 2359, 2366, 2373, 2387, 2394, 2401, 2408, 2422, 2429, 2436, 2443, 2457, 2464, 2471, 2478, 2492, 2499, 2506, 2513, 2527, 2534, 2541, 2548, 2562, 2569, 2576, 2583, 2597, 2604, 2611, 2618, 2632, 2639, 2646, 2653, 2667, 2674, 2681, 2688, 2702, 2709, 2716, 2723, 2737, 2744, 2751, 2758, 2772, 2779, 2786, 2793, 2807, 2814, 2821, 2828, 2842, 2849, 2856, 2863, 2877, 2884, 2891, 2898, 2912, 2919, 2926, 2933, 2947, 2954, 2961, 2968, 2982, 2989, 2996, 3003, 3017, 3024, 3031, 3038, 3052, 3059, 3066, 3073, 3087, 3094, 3101, 3108, 3122, 3129, 3136, 3143, 3157, 3164, 3171, 3178, 3192, 3199]

# %% [markdown]
# 6. What is the output of the following code examples?
#
# ```
# 1.x=123
#     for i in x:
#     print(i)
#
# 2.i = 0
#   while i < 5:
#     print(i)
#     i += 1
#     if i == 3:
#       break
#     else:
#       print(“error”)
#
# 3.count = 0
#   while True:
#     print(count)
#     count += 1
#     if count >= 5:
#       break
# ```

# %% [markdown]
# Outputs:
#
# 1. Error, since integer is not iterable.
#
# 2.  0  error  1  error  2
#
# 3.  0  1  2  3  4

# %% [markdown]
# 7. Write a program that prints all the numbers from 0 to 6 except 3 and 6.
# Expected output: 0 1 2 4 5
# Note: Use ‘continue’ statement

# %%
for num in range(0, 7):
  if (num == 3) | (num == 6):
    continue
  else:
    print(num)
# Out:
# 0
# 1
# 2
# 4
# 5

# %% [markdown]
# 8. Write a program that accepts a string as an input from the user and calculate the number of digits
# and letters.
#
#   Sample input: consul72
#
#   Expected output: Letters 6 Digits 2

# %%
value = input('Enter a string: ')

digits, letters = 0, 0

for ele in value:
   if ele.isdigit():
      digits += 1
   elif ele.isalpha():
      letters += 1

print(f"Letters {letters} Digits {digits}")
# Out:
# Enter a string: g9js5v7
# Letters 4 Digits 3

# %% [markdown]
# 9. Read the two parts of the question below:
#
# *   Write a program such that it asks users to “guess the lucky number”. If the correct number is guessed the program stops, otherwise it continues forever.
#
# *   Modify the program so that it asks users whether they want to guess again each time. Use two variables, ‘number’ for the number and ‘answer’ for the answer to the question whether they want to continue guessing. The program stops if the user guesses the correct number or answers “no”. (The program continues as long as a user has not answered “no” and has not guessed the correct
# number)

# %%
# Part I

lucky_num = 8

while True:
  num = input('Guess the lucky number: ')
  num = int(num)

  if num == lucky_num:
    break
# Out:
# Guess the lucky number: 7
# Guess the lucky number: 1
# Guess the lucky number: 0
# Guess the lucky number: 6
# Guess the lucky number: 9
# Guess the lucky number: 1
# Guess the lucky number: 3
# Guess the lucky number: 8

# %%
# Part II

lucky_num = 4

while True:
  number = input('Guess the lucky number: ')
  number = int(number)

  if number == lucky_num:
    break
  else:
    answer = input("Enter 'No' to stop OR press 'Enter' to continue: ")
    if answer == 'No':
      break
# Out:
# Guess the lucky number: 3
# Enter 'No' to stop OR press 'Enter' to continue:
# Guess the lucky number: 6
# Enter 'No' to stop OR press 'Enter' to continue:
# Guess the lucky number: 7
# Enter 'No' to stop OR press 'Enter' to continue: No

# %% [markdown]
# 10. Write a program that asks five times to guess the lucky number. Use a while loop and a counter,
# such as
#
# ```
# counter=1
# while counter <= 5:
#   print(“Type in the”, counter, “number”
#   counter=counter+1
# ```
#
# The program asks for five guesses (no matter whether the correct number was guessed or not). If the correct number is guessed, the program outputs “Good guess!”, otherwise it outputs “Try again!”. After the fifth guess it stops and prints “Game over!”.

# %%
lucky_num = 2
counter = 1

while counter <= 5:
  number = input('Guess the lucky number: ')
  number = int(number)
  if number == lucky_num:
    print('Good guess!')
  elif counter == 5:
    print('Game over!')
  else:
    print('Try again!')
  counter += 1
# Out:
# Guess the lucky number: 4
# Try again!
# Guess the lucky number: 7
# Try again!
# Guess the lucky number: 2
# Good guess!
# Guess the lucky number: 6
# Try again!
# Guess the lucky number: 8
# Game over!

# %% [markdown]
# 11. In the previous question, insert break after the “Good guess!” print statement. break will terminate
# the while loop so that users do not have to continue guessing after they found the number. If the user
# does not guess the number at all, print “Sorry but that was not very successful”.

# %%
lucky_num = 7
counter = 1

while counter <= 5:
  number = input('Guess the lucky number: ')
  number = int(number)
  if number == lucky_num:
    print('Good guess!')
    break
  elif counter == 5:
    print('Sorry but that was not very successful.')
  else:
    print('Try again!')
  counter += 1
# Out:
# Guess the lucky number: 1
# Try again!
# Guess the lucky number: 6
# Try again!
# Guess the lucky number: 7
# Good guess!
